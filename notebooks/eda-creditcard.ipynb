# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/creditcard.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Data Quality Check
#
# The dataset has no missing values across all columns.
# This indicates that the data is already preprocessed and clean, which is common for credit card fraud datasets.

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x="Class", data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
sns.histplot(df["Amount"])
sns.histplot(df["Time"])
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.boxplot(x="Class", y="Amount", data=df)
plt.show()

# %%
sns.boxplot(x="Class", y="Time", data=df)
# Out:
# <Axes: xlabel='Class', ylabel='Time'>

# %%
"""
Observations:
- Dataset is highly imbalanced (fraud cases are rare)
- Fraud transactions tend to have different amount distribution
- Most transactions are non-fraud
"""
# Out:
# '\nObservations:\n- Dataset is highly imbalanced (fraud cases are rare)\n- Fraud transactions tend to have different amount distribution\n- Most transactions are non-fraud\n'

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), cmap="coolwarm", annot=False)
plt.show()

# %%
sns.histplot(df["Amount"])
plt.show()
